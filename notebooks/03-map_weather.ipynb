# %%
import pandas as pd
import folium
import requests
import support_weather as sw

# %%
df = pd.read_csv("../files/03-areas_country.csv", index_col= 0)
df.head()
# Out:
#    latitude  longitude         town                region country   price  \
# 0  39.06956   -0.40980   Carcaixent  Comunitat Valenciana  España    Free
# 1  42.64159   -8.89696        Boiro               Galicia  España    Free
# 2  42.90715    0.35921       Arreau             Occitanie  France  Paying
# 3  38.39479   -0.41007  el Campello  Comunitat Valenciana  España  Paying
# 4  43.37179   -8.44443     A Coruña               Galicia  España    Free
#
#   water   wc grey_water
# 0   yes  yes        yes
# 1   yes  yes    unknown
# 2   yes   no        yes
# 3   yes  yes    unknown
# 4   yes  yes    unknown

# %%
map = folium.Map(location=[df.latitude.mean(), df.longitude.mean()], zoom_start=5, control_scale=True)

for index, location_info in df.iterrows():
    if location_info["price"] == "Free":
        folium.Marker([location_info["latitude"], location_info["longitude"]], tooltip=location_info["town"], popup=index, icon=folium.Icon(color='blue', prefix='fa',icon='van-shuttle')).add_to(map)
    elif location_info["price"] == "Paying":
        folium.Marker([location_info["latitude"], location_info["longitude"]], tooltip = location_info["town"], popup=index, icon=folium.Icon(color='red', prefix='fa',icon='van-shuttle')).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2139be2473d61acb7add37b785fe57ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2139be2473d61acb7add37b785fe57ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2139be2473d61acb7add37b785fe57ca = L.map(
#                 &quot;map_2139be2473d61acb7add37b785fe57ca&quot;,
#                 {
#                     center: [44.362593515881706, 1.141285717415115],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2139be2473d61acb7add37b785fe57ca);
#
#
#
#
#
#             var tile_layer_180331342f482d1b51c67aa460b83981 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2139be2473d61acb7add37b785fe57ca);
#
#
#             var marker_32b0ab99e82099b53cd6ce94a74f306b = L.marker(
#                 [39.06956, -0.4098],
#                 {}
#             ).addTo(map_2139be2473d61acb7add37b785fe57ca);
#
#
#             var icon_fc8e26392e100862c47fefc69490e555 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;van-shuttle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_32b0ab99e82099b53cd6ce94a74f306b.setIcon(icon_fc8e26392e100862c47fefc69490e555);
#
#
#         var popup_ec0ec7e171f4444d64dcedec6cd11b37 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1436f7c8420a64b96a9a5881de9500a0 = $(`&lt;div id=&quot;html_1436f7c8420a64b96a9a5881de9500a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_ec0ec7e171f4444d64dcedec6cd11b37.setContent(html_1436f7c8420a64b96a9a5881de9500a0);
#
#
#
#         marker_32b0ab99e82099b53cd6ce94a74f306b.bindPopup(popup_ec0ec7e171f4444d64dcedec6cd11b37)
#         ;
#
#
#
#
#             marker_32b0ab99e82099b53cd6ce94a74f306b.bindTooltip(
#                 `&lt;div&gt;
#                      Carcaixent
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92c5fd3d2a9d1fdd249f71828567eb59 = L.marker(
#                 [42.64159, -8.89696],
#                 {}
#             ).addTo(map_2139be2473d61acb7add37b785fe57ca);
#
#
#             var icon_1d5294a4159dc488dfbb72d05dcb2dd5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;van-shuttle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_92c5fd3d2a9d1fdd249f71828567eb59.setIcon(icon_1d5294a4159dc488dfbb72d05dcb2dd5);
#
#
#         var popup_5558cd69d2e99e1660600844c4611794 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_172b580de357c6bf6375850d83f7e5ab = $(`&lt;div id=&quot;html_172b580de357c6bf6375850d83f7e5ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_5558cd69d2e99e1660600844c4611794.setContent(html_172b580de357c6bf6375850d83f7e5ab);
#
#
#
#         marker_92c5fd3d2a9d1fdd249f71828567eb59.bindPopup(popup_5558cd69d2e99e1660600844c4611794)
#         ;
#
#
#
#
#             marker_92c5fd3d2a9d1fdd249f71828567eb59.bindTooltip(
#                 `&lt;div&gt;
#                      Boiro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e215bb5b017314606b0490c6feebd9c4 = L.marker(
#                 [42.90715, 0.35921],
#                 {}
#             ).addTo(map_2139be2473d61acb7add37b785fe57ca);
#
#
#             var icon_7b440f7ffa6a0a994f9a80609d79569f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;van-shuttle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e215bb5b017314606b0490c6feebd9c4.setIcon(icon_7b440f7ffa6a0a994f9a80609d79569f);
#
#
#         var popup_8a921abc1d737d439bd814a76714078d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9061d74f3ad5fde5a265db0579700da = $(`&lt;div id=&quot;html_e9061d74f3ad5fde5a265db0579700da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_8a921abc1d737d439bd814a76714078d.setContent(html_e9061d74f3ad5fde5a265db0579700da);
#
#
#
#         marker_

# %%
df1 = sw.clima(df, 522)
df1
# Out:
#            2023-02-09 2023-02-10 2023-02-11 2023-02-12 2023-02-13 2023-02-14  \
# Weather  Mainly clear  Clear sky   Overcast   Overcast  Clear sky        Fog
#
#         2023-02-15
# Weather        Fog
