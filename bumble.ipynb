# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datos_areas_internet/OurBumble-DB.csv")

# %%
df.head()
# Out:
#    Country       Town Site Name           Location  \
# 0  Andorra    Canillo       NaN        Countryside
# 1  Andorra     Ordino       NaN        Countryside
# 2  Andorra     Ordino       NaN  Village/Town/City
# 3  Andorra     Arcais       NaN        Countryside
# 4  Andorra  El Serrat       NaN        Countryside
#
#                                             Services   Cost  Altitude  \
# 0                                                NaN  €0.00    1284.0
# 1                                              Trash  €0.00    1984.0
# 2  Fresh Water
# Grey Water
# Black Water
# Trash
# Toile...  €7.00    1288.0
# 3                                    Toilets
# Showers  €0.00    2223.0
# 4                                              Trash  €0.00    1940.0
#
#     Latitude  Longitude                                        Website URL  \
# 0  42.572822   1.586612  http://ourbumble.com/llorvorsi-to-villefranche...
# ...

# %%
df.shape
# Out:
# (767, 12)

# %%
df["Site Type"].value_counts()
# Out:
# Mixed Parking               437
# Wild                        171
# Rest Area & Services         67
# Campsite                     31
# Rest Area                    29
# Mixed Parking & Services     14
# Service Only                 13
# Layby                         3
# Name: Site Type, dtype: int64

# %%
for i in df.columns:
    print(i, "-->", df[i].value_counts())
# Out:
# Country --> Greece         112
# Spain          104
# Germany         98
# Norway          78
# Portugal        77
# Finland         61
# Italy           54
# France          51
# Estonia         19
# Denmark         16
# Slovenia        14
# Latvia          12
# Poland          12
# Romania          9
# Slovakia         8
# Lithuania        7
# Sweden           7
# Andorra          6
# Austria          6
# Belgium          5
# Switzerland      4
# Bulgaria         3
# Hungary          2
# Netherlands      1
# Name: Country, dtype: int64
# Town --> Inari            9
# Turku            7
# Vila Do Bispo    4
# Vuotso           4
# Helsinki         4
#                 ..
# Poulithra        1
# Kivario          1
# Kiveriou         1
# Nea Kios         1
# Greebbestad      1
# Name: Town, Length: 582, dtype: int64
# Site Name --> Isla de Faro              2
# Kampeerautoterain 1       1
# Osir Eurocamping          1
# Belem                     1
# Doca de Alcantara         1
# ...
