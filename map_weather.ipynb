# %%
import pandas as pd
import folium
import requests
import support_weather as sw

# %%
df = pd.read_csv("ficheros/areas_limpio.csv", index_col= 0)
df.head()
# Out:
#    latitude  longitude         town                region country   price  \
# 0  39.06956   -0.40980   Carcaixent  Comunitat Valenciana  España    Free
# 1  42.64159   -8.89696        Boiro               Galicia  España    Free
# 2  42.90715    0.35921       Arreau             Occitanie  France  Paying
# 3  38.39479   -0.41007  el Campello  Comunitat Valenciana  España  Paying
# 4  43.37179   -8.44443     A Coruña               Galicia  España    Free
#
#   water   wc grey_water
# 0   yes  yes        yes
# 1   yes  yes    unknown
# 2   yes   no        yes
# 3   yes  yes    unknown
# 4   yes  yes    unknown

# %%
map = folium.Map(location=[df.latitude.mean(), df.longitude.mean()], zoom_start=5, control_scale=True)

for index, location_info in df.iterrows():
    if location_info["price"] == "Free":
        folium.Marker([location_info["latitude"], location_info["longitude"]], tooltip=location_info["town"], popup=index, icon=folium.Icon(color='blue', prefix='fa',icon='van-shuttle')).add_to(map)
    elif location_info["price"] == "Paying":
        folium.Marker([location_info["latitude"], location_info["longitude"]], tooltip = location_info["town"], popup=index, icon=folium.Icon(color='red', prefix='fa',icon='van-shuttle')).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f588eaacf83ab5bafeb9b52a234cf369 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f588eaacf83ab5bafeb9b52a234cf369&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f588eaacf83ab5bafeb9b52a234cf369 = L.map(
#                 &quot;map_f588eaacf83ab5bafeb9b52a234cf369&quot;,
#                 {
#                     center: [44.362593515881706, 1.141285717415115],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f588eaacf83ab5bafeb9b52a234cf369);
#
#
#
#
#
#             var tile_layer_cf298e7a3f0daefb2d22453b76ded839 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f588eaacf83ab5bafeb9b52a234cf369);
#
#
#             var marker_4e469812660fbac2d3fa16a36eababf9 = L.marker(
#                 [39.06956, -0.4098],
#                 {}
#             ).addTo(map_f588eaacf83ab5bafeb9b52a234cf369);
#
#
#             var icon_8f0857a026702fa7373e1f260fc29e82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;van-shuttle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4e469812660fbac2d3fa16a36eababf9.setIcon(icon_8f0857a026702fa7373e1f260fc29e82);
#
#
#         var popup_0080ce354622c99c5d94fcd6fe5b2567 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b3cf99dd8aaa10381cd1608234e7533 = $(`&lt;div id=&quot;html_5b3cf99dd8aaa10381cd1608234e7533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_0080ce354622c99c5d94fcd6fe5b2567.setContent(html_5b3cf99dd8aaa10381cd1608234e7533);
#
#
#
#         marker_4e469812660fbac2d3fa16a36eababf9.bindPopup(popup_0080ce354622c99c5d94fcd6fe5b2567)
#         ;
#
#
#
#
#             marker_4e469812660fbac2d3fa16a36eababf9.bindTooltip(
#                 `&lt;div&gt;
#                      Carcaixent
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_03b4f0db67a02b47367415c8711b03b7 = L.marker(
#                 [42.64159, -8.89696],
#                 {}
#             ).addTo(map_f588eaacf83ab5bafeb9b52a234cf369);
#
#
#             var icon_1f03455ace3914507f8ad5387321dd9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;van-shuttle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_03b4f0db67a02b47367415c8711b03b7.setIcon(icon_1f03455ace3914507f8ad5387321dd9a);
#
#
#         var popup_33dd1eb72b2c3626972542034f2823c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ec158af1b1f0345c28a2648c8782a21 = $(`&lt;div id=&quot;html_6ec158af1b1f0345c28a2648c8782a21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_33dd1eb72b2c3626972542034f2823c0.setContent(html_6ec158af1b1f0345c28a2648c8782a21);
#
#
#
#         marker_03b4f0db67a02b47367415c8711b03b7.bindPopup(popup_33dd1eb72b2c3626972542034f2823c0)
#         ;
#
#
#
#
#             marker_03b4f0db67a02b47367415c8711b03b7.bindTooltip(
#                 `&lt;div&gt;
#                      Boiro
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_49e1a9ffdcab22546fc772b15565bdcc = L.marker(
#                 [42.90715, 0.35921],
#                 {}
#             ).addTo(map_f588eaacf83ab5bafeb9b52a234cf369);
#
#
#             var icon_35dec3f6577ddd9177ed13b01c78a84d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;van-shuttle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_49e1a9ffdcab22546fc772b15565bdcc.setIcon(icon_35dec3f6577ddd9177ed13b01c78a84d);
#
#
#         var popup_6a357816f51a4d0233f9c118253cd00d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30a65118f3cf9ef70df0c4d4eb4c25b2 = $(`&lt;div id=&quot;html_30a65118f3cf9ef70df0c4d4eb4c25b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_6a357816f51a4d0233f9c118253cd00d.setContent(html_30a65118f3cf9ef70df0c4d4eb4c25b2);
#
#
#
#         marker_

# %%
df1 = sw.clima(df, 522)
df1
# Out:
#         2023-01-31 2023-02-01 2023-02-02 2023-02-03 2023-02-04 2023-02-05  \
# Weather        Fog        Fog        Fog        Fog        Fog   Overcast
#
#         2023-02-06
# Weather        Fog

# %%
class Areas:
    def __init__(self, dataf):

        self.dataf = dataf

    # Creamos un método para crear el mapa

    def crear_mapa(self):
        map = folium.Map(location=[df.latitude.mean(), df.longitude.mean()], zoom_start=5, control_scale=True)

        for index, location_info in df.iterrows():
            if location_info["price"] == "Free":
                folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["town"], icon=folium.Icon(color='blue', prefix='fa',icon='van-shuttle')).add_to(map)
            elif location_info["price"] == "Paying":
                folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["town"], icon=folium.Icon(color='red', prefix='fa',icon='van-shuttle')).add_to(map)
        return map
